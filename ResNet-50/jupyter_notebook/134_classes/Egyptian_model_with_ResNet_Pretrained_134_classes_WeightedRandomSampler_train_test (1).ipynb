# %%
import os, os.path
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from pathlib import Path
from torchvision import datasets, models, transforms

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

# %% [markdown]
# Module: Load_data

# %%
def get_class_distribution(dataset_obj, idx2class):
    count_dict = {k:0 for k,v in dataset_obj.class_to_idx.items()}
    
    for element in dataset_obj:
        y_lbl = element[1]
        y_lbl = idx2class[y_lbl]
        count_dict[y_lbl] += 1
            
    return count_dict

# %%
def load_data(hieroglyph_directory_path, batch_size=20, num_workers=0):
    train_dir = os.path.join(hieroglyph_directory_path, 'train/')
    test_dir = os.path.join(hieroglyph_directory_path, 'test/')

    classes = []

    for filename in os.listdir(train_dir):
        if filename == '.DS_Store':
            pass
        else:
            classes.append(filename)

    classes.sort()

    # print("Our classes:", classes)
    # print(len(classes))

    data_transform = transforms.Compose([transforms.ToTensor(),
                                            transforms.RandomApply([transforms.RandomHorizontalFlip()]),
                                            transforms.RandomRotation(degrees=(-10, 10)),
                                            transforms.RandomAffine(degrees=0, translate=(.1, .1)),
                                            transforms.RandomApply([transforms.ColorJitter(brightness=(1, 1.2),
                                                                                            contrast=(1, 1.5),
                                                                                            saturation=(1, 1.5),
                                                                                            hue=(0, 0.5))]),
                                            transforms.RandomErasing(p=0.5, scale=(0.05, 0.05), ratio=(0.3, 3.3), value=0,
                                                                      inplace=False),
                                            transforms.Normalize((0.5,), (0.5,))])

    train_data = datasets.ImageFolder(train_dir, transform=data_transform)
    test_data = datasets.ImageFolder(test_dir, transform=data_transform)

    # print('Num training images: ', len(train_data))
    # print('Num test images: ', len(test_data))

    # WeightedRandomSampler for train loader
    idx2class = {v: k for k, v in train_data.class_to_idx.items()}

    target_list = torch.tensor(train_data.targets)
    class_count = [i for i in get_class_distribution(train_data, idx2class).values()]
    class_weights = 1./torch.tensor(class_count, dtype=torch.float) 
    class_weights_all = class_weights[target_list]
    weighted_sampler = torch.utils.data.WeightedRandomSampler(weights=class_weights_all, num_samples=len(class_weights_all), replacement=True)

    # prepare data loaders
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                               num_workers=num_workers, sampler=weighted_sampler, drop_last=True)
    
    # WeightedRandomSampler for test loader
    idx2class_test = {v: k for k, v in test_data.class_to_idx.items()}

    target_list_test = torch.tensor(test_data.targets)
    class_count_test = [i for i in get_class_distribution(test_data, idx2class_test).values()]
    class_weights_test = 1./torch.tensor(class_count_test, dtype=torch.float) 
    class_weights_all_test = class_weights_test[target_list_test]
    weighted_sampler_test = torch.utils.data.WeightedRandomSampler(weights=class_weights_all_test, num_samples=len(class_weights_all_test), replacement=True)

    test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,
                                              num_workers=num_workers, sampler=weighted_sampler_test)

    return train_loader, test_loader, classes

# %% [markdown]
# Module: Train_model

# %%
def train_model(train_loader, optimizer, resnet50, criterion, my_lr_scheduler, n_epochs):
    # track training loss over time
    losses = []
    
    for epoch in range(1, n_epochs + 1):

        # keep track of training and validation loss
        train_loss = 0.0

        # model by default is set to train
        for batch_i, (data, target) in enumerate(train_loader):
            # move tensors to GPU if CUDA is available
            if train_on_gpu:
                data, target = data.cuda(), target.cuda()
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = resnet50(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update training loss
            train_loss += loss.item()

            my_lr_scheduler.step()

            if batch_i % 20 == 19:  # print training loss every specified number of mini-batches
                print('Epoch %d, Batch %d loss: %.16f' %
                    (epoch, batch_i + 1, train_loss / 20))
                losses.append(train_loss / 20)
                train_loss = 0.0
        
        

    return resnet50, losses

# %% [markdown]
# Module: Test_model

# %%
def test_model(classes, resnet50, test_loader, criterion):
    # track test loss
    test_loss = 0.0
    class_correct = list(0. for i in range(len(classes)))
    class_total = list(0. for i in range(len(classes)))

    resnet50.eval()  # eval mode

    labels = []
    predictions = []
    # iterate over test data
    for data, target in test_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = resnet50(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update  test loss
        test_loss += loss.item() * data.size(0)
        # convert output probabilities to predicted class
        _, pred = torch.max(output, 1)
        # compare predictions to true label
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
        # calculate test accuracy for each object class
        for i in range(len(target.data)):
            label = target.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1
        
        # Will be used for calculating Recall, Precision, and F1-score
        labels.extend(target.data.view_as(pred).tolist())
        predictions.extend(pred.tolist())


    # calculate avg test loss
    test_loss = test_loss / len(test_loader.dataset)
    print('Test Loss: {:.6f}\n'.format(test_loss))

    return test_loss, class_correct, class_total, labels, predictions

# %% [markdown]
# Check whether CUDA is available (Change runtime type if not)

# %%
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# Load Hieroglyph Data

# %%
# Connecting and Mounting to the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/EgyptianHieroglyphDataset_134/'

# %%
hieroglyph_for_train = []
file_count_list = []

for name in os.listdir('/content/drive/MyDrive/EgyptianHieroglyphDataset_134/train/'):
  path, dirs, files = next(os.walk("/content/drive/MyDrive/EgyptianHieroglyphDataset_134/train/"+name))
  file_count = len(files)
  print(name, file_count)
  file_count_list.append(file_count)
  hieroglyph_for_train.append(name)

hieroglyph_dict = dict(zip(hieroglyph_for_train, file_count_list))
# Out:
# Aa15 2
# Aa26 4
# Aa27 2
# Z1 39
# Z11 8
# Z7 3
# Y2 5
# Y3 2
# Y5 6
# E34 97
# E1 5
# E23 8
# E9 8
# W18 5
# W24 31
# W11 4
# W22 1
# W19 3
# W25 9
# D21 146
# D4 29
# D46 40
# D1 4
# D36 47
# D58 28
# D2 19
# D35 45
# D60 4
# D28 13
# D10 2
# D39 1
# D56 2
# D19 2
# D52 4
# D54 9
# D156 2
# X1 185
# X8 4
# U15 10
# U28 2
# U1 20
# U33 13
# U7 3
# T28 1
# T22 7
# T21 2
# T20 3
# T30 2
# V31 106
# V28 28
# V13 63
# V4 10
# V30 6
# V7 4
# V24 4
# V6 1
# R8 53
# R4 2
# Q3 61
# Q1 13
# Q7 2
# P8 12
# P6 2
# P98 4
# P1 4
# S29 212
# S34 8
# S24 1
# S28 1
# O50 84
# O49 10
# O28 8
# O34 15
# O1 16
# O31 5
# O4 11
# I9 116
# I10 32
# G17 156
# L1 2
# M17 291
# M44 5
# M42 4
# M1 2
# M12 2
# M18 10
# M195 2
# M20 2
# M23 30
# M41 2
# M3 3
# M16 1
# M8 1
# M40 2
# M29 2
# H6 5
# N35 358
# N5 16
# N1 14
# N37 24
# N14 11
# N31 13
# N17 6
# N29 14
# N18 15
# N41 2
# N30 9
# N25 1
# N36 1
# F13 6
# F16 5
# F35 2
# F34 8
# F31 6
# F4 3
# F40 1
# F18 4
# F9 2
# F26 3
# G39 16
# G43 157
# G5 24
# G40 6
# G7 8
# G35 30
# G1 28
# G21 1
# G25 21
# G36 7
# G4 6
# G14 1
# G26 1
# G29 2
# G37 2

# %% [markdown]
# Number of images for each hieroglyph

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({"Hieroglyph":hieroglyph_for_train, "Count":file_count_list})

df_sorted= df.sort_values('Count',ascending=False)

plt.figure(figsize=(20,10))
# make bar plot with matplotlib
plt.bar('Hieroglyph', 'Count',data=df_sorted)
# Out:
# <BarContainer object of 134 artists>

# %%
# Number of images processed in a single training
batch_size = 20
num_workers = 0

# The load_data function is from hieroglyph_data_preparation python file
train_loader, test_loader, classes = load_data(data_dir)

# %% [markdown]
# ResNet Model

# %%
# Whether to extract features with the model
feature_extract = False
# Other selections
loss_function = "cross-entropy"
model_selection = "resnet-50"
optim_selection = "Adam"

# False if you want scratch model, True if you want pretrained model
whether_to_pretrain = True

# Load the model
if model_selection == "resnet-50":
    resnet50 = models.resnet50(pretrained=whether_to_pretrain)

# Number of features in the last layer of resnet
n_inputs = resnet50.fc.in_features

# Add last linear layer (n_inputs -> 40 hieroglyph classes)
# New layers automatically have requires_grad = True
last_layer = nn.Sequential(
                nn.Linear(n_inputs, len(classes)))

resnet50.fc = last_layer

# if GPU is available, move the model to GPU
if train_on_gpu:
    resnet50.cuda()

# Specify loss function (categorical cross-entropy)
if loss_function == "cross-entropy":
    criterion = nn.CrossEntropyLoss()

# Specify optimizer (Adam) and learning rate = 0.001
if optim_selection == "Adam":
    optimizer = optim.Adam(resnet50.parameters(), lr=0.001)

# Exponential Decay to strengthen learning
decayRate = 0.999
my_lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=decayRate)

# %% [markdown]
# Training the model

# %%
# number of epochs to train the model
n_epochs = 50

# The train_model function is from model_training python file
resnet50, train_losses = train_model(train_loader, optimizer, resnet50, criterion, my_lr_scheduler, n_epochs)
# Out:
# Epoch 1, Batch 20 loss: 5.5376530885696411
# Epoch 1, Batch 40 loss: 5.2486333131790159
# Epoch 1, Batch 60 loss: 5.1102771997451786
# Epoch 1, Batch 80 loss: 4.8028265714645384
# Epoch 1, Batch 100 loss: 4.5987942695617674
# Epoch 1, Batch 120 loss: 4.4124332308769230
# Epoch 1, Batch 140 loss: 4.3341833114624020
# Epoch 2, Batch 20 loss: 4.0437959313392637
# Epoch 2, Batch 40 loss: 4.1026985526084898
# Epoch 2, Batch 60 loss: 3.9796304106712341
# Epoch 2, Batch 80 loss: 3.9160907268524170
# Epoch 2, Batch 100 loss: 3.7651469111442566
# Epoch 2, Batch 120 loss: 3.7008469343185424
# Epoch 2, Batch 140 loss: 3.6586076974868775
# Epoch 3, Batch 20 loss: 3.5965294599533082
# Epoch 3, Batch 40 loss: 3.5859448075294496
# Epoch 3, Batch 60 loss: 3.4948972463607788
# Epoch 3, Batch 80 loss: 3.3162133574485777
# Epoch 3, Batch 100 loss: 3.0677652120590211
# Epoch 3, Batch 120 loss: 3.0426775336265566
# Epoch 3, Batch 140 loss: 2.8738031029701232
# Epoch 4, Batch 20 loss: 2.6933418512344360
# Epoch 4, Batch 40 loss: 2.6717227220535280
# Epoch 4, Batch 60 loss: 2.5194503903388976
# Epoch 4, Batch 80 loss: 2.2901161372661591
# Epoch 4, Batch 100 loss: 2.1645152866840363
# Epoch 4, Batch 120 loss: 2.1321223974227905
# Epoch 4, Batch 140 loss: 2.0391916155815126
# Epoch 46, Batch 80 loss: 0.0975494117476046
# Epoch 46, Batch 100 loss: 0.0908027788624167
# Epoch 46, Batch 120 loss: 0.1162373744882643
# Epoch 46, Batch 140 loss: 0.1051231599412858
# Epoch 47, Batch 20 loss: 0.0990832974202931
# Epoch 47, Batch 40 loss: 0.1431615821085870
# Epoch 47, Batch 60 loss: 0.0841757307760417
# Epoch 47, Batch 80 loss: 0.1100856757722795
# Epoch 47, Batch 100 loss: 0.1096848658286035
# Epoch 47, Batch 120 loss: 0.1091136471368372
# Epoch 47, Batch 140 loss: 0.0955481516662985
# Epoch 48, Batch 20 loss: 0.1216954356990755
# Epoch 48, Batch 40 loss: 0.0841461671516299
# Epoch 48, Batch 60 loss: 0.0899690460879356
# Epoch 48, Batch 80 loss: 0.0801162735559046
# Epoch 48, Batch 100 loss: 0.0897267444524914
# Epoch 48, Batch 120 loss: 0.1325437078252435
# Epoch 48, Batch 140 loss: 0.1350721452385187
# Epoch 49, Batch 20 loss: 0.1226255338173360
# Epoch 49, Batch 40 loss: 0.0916880496311933
# Epoch 49, Batch 60 loss: 0.1411668735556305
# Epoch 49, Batch 80 loss: 0.1387275465764105
# Epoch 49, Batch 100 loss: 0.0899342502467334
# Epoch 49, Batch 120 loss: 0.1122734174132347
# Epoch 49, Batch 140 loss: 0.1184383636340499
# Epoch 50, Batch 20 loss: 0.0939483893103898
# Epoch 50, Batch 40 loss: 0.0802519686054438
# Epoch 50, Batch 60 loss: 0.0930464303586632
# Epoch 50, Batch 80 loss: 0.1049471337348223
# Epoch 50, Batch 100 loss: 0.1266116233542562
# Epoch 50, Batch 120 loss: 0.0823746693786234
# Epoch 50, Batch 140 loss: 0.1107334895990789

# %%
plt.plot(train_losses)
plt.title("Training Loss")
plt.show()

# %% [markdown]
# Testing the model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
# The test_model function is from model_testing python file
test_loss, class_correct, class_total, labels, predictions = test_model(classes, resnet50, test_loader, criterion)

# Test accuracy for each hieroglyph
for i in range(len(classes)):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (classes[i], 100 * class_correct[i] / class_total[i], np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

# Total Test accuracy
print("\nAccuracy: {:.3%}".format(accuracy_score(labels, predictions)))
print("\nPrecision: {:.3%}".format(precision_score(labels, predictions, average = 'weighted')))
print("\nRecall: {:.3%}".format(recall_score(labels, predictions, average = 'weighted')))
print("\nF1-score: {:.3%}".format(f1_score(labels, predictions, average = 'weighted')))
# Out:
# Test Loss: 1.465192
#
# Test Accuracy of  Aa15: 100% ( 8/ 8)
# Test Accuracy of  Aa26: 100% ( 5/ 5)
# Test Accuracy of  Aa27: 88% ( 8/ 9)
# Test Accuracy of    D1: 100% ( 3/ 3)
# Test Accuracy of   D10:  0% ( 0/ 8)
# Test Accuracy of  D156: 100% ( 6/ 6)
# Test Accuracy of   D19:  0% ( 0/ 4)
# Test Accuracy of    D2: 100% ( 9/ 9)
# Test Accuracy of   D21: 80% ( 4/ 5)
# Test Accuracy of   D28: 100% ( 6/ 6)
# Test Accuracy of   D35: 100% ( 7/ 7)
# Test Accuracy of   D36: 75% ( 3/ 4)
# Test Accuracy of   D39: 100% (15/15)
# Test Accuracy of    D4: 100% ( 7/ 7)
# Test Accuracy of   D46: 71% ( 5/ 7)
# Test Accuracy of   D52: 100% ( 3/ 3)
# Test Accuracy of   D54: 100% ( 7/ 7)
# Test Accuracy of   D56: 50% ( 3/ 6)
# Test Accuracy of   D58: 100% ( 6/ 6)
# Test Accuracy of   D60: 100% ( 4/ 4)
# Test Accuracy of    E1: 100% ( 5/ 5)
# Test Accuracy of   E23: 72% ( 8/11)
# Test Accuracy of   E34: 100% (11/11)
# Test Accuracy of    E9: 33% ( 1/ 3)
# Test Accuracy of   F13: 100% ( 8/ 8)
# Test Accuracy of   F16: 80% ( 4/ 5)
# Test Accuracy of   F18: 75% ( 6/ 8)
# Test Accuracy of   F26: 100% ( 4/ 4)
# Test Accuracy of   F31: 100% ( 6/ 6)
# Test Accuracy of   F34: 100% ( 4/ 4)
# Test Accuracy of   F35: 100% (11/11)
# Test Accuracy of    F4: 100% ( 9/ 9)
# Test Accuracy of   F40: 100% ( 5/ 5)
# Test Accuracy of    F9: 62% ( 5/ 8)
# Test Accuracy of    G1: 40% ( 2/ 5)
# Test Accuracy of   G14: 20% ( 1/ 5)
# Test Accuracy of   G17: 100% ( 5/ 5)
# Test Accuracy of   G21: 71% ( 5/ 7)
# Test Accuracy of   G25: 75% ( 3/ 4)
# Test Accuracy of   G26: 75% ( 9/12)
# Test Accuracy of   G29:  0% ( 0/ 5)
# Test Accuracy of   G35: 57% ( 4/ 7)
# Test Accuracy of   G36: 88% ( 8/ 9)
# Test Accuracy of   G37: 77% ( 7/ 9)
# Test Accuracy of   G39: 85% ( 6/ 7)
# Test Accuracy of    G4: 40% ( 2/ 5)
# Test Accuracy of   G40: 100% (12/12)
# Test Accuracy of   G43: 100% ( 4/ 4)
# Test Accuracy of    G5: 66% ( 4/ 6)
# Test Accuracy of    G7: 100% ( 3/ 3)
# Test Accuracy of    H6: 62% ( 5/ 8)
# Test Accuracy of   I10: 100% ( 6/ 6)
# Test Accuracy of    I9: 100% ( 5/ 5)
# Test Accuracy of    L1: 20% ( 1/ 5)
# Test Accuracy of    M1: 30% ( 3/10)
# Test Accuracy of   M12: 60% ( 3/ 5)
# Test Accuracy of   M16: 100% ( 6/ 6)
# Test Accuracy of   M17: 100% ( 6/ 6)
# Test Accuracy of   M18: 100% (10/10)
# Test Accuracy of  M195:  0% ( 0/ 4)
# Test Accuracy of   M20: 100% ( 3/ 3)
# Test Accuracy of   M23: 100% ( 7/ 7)
# Test Accuracy of   M29: 20% ( 2/10)
# Test Accuracy of    M3:  0% ( 0/ 5)
# Test Accuracy of   M40: 100% ( 4/ 4)
# Test Accuracy of   M41: 100% ( 4/ 4)
# Test Accuracy of   M42: 50% ( 1/ 2)
# Test Accuracy of   M44: 60% ( 3/ 5)
# Test Accuracy of    M8: 33% ( 2/ 6)
# Test Accuracy of    N1: 100% ( 6/ 6)
# Test Accuracy of   N14: 100% ( 4/ 4)
# Test Accuracy of   N17: 50% ( 3/ 6)
# Test Accuracy of   N18: 50% ( 1/ 2)
# Test Accuracy of   N25: 100% (10/10)
# Test Accuracy of   N29: 100% ( 4/ 4)
# Test Accuracy of   N30: 100% (10/10)
# Test Accuracy of   N31: 100% ( 5/ 5)
# Test Accuracy of   N35: 87% ( 7/ 8)
# Test Accuracy of   N36:  0% ( 0/ 6)
# Test Accuracy of   N37: 66% ( 4/ 6)
# Test Accuracy of   N41: 71% ( 5/ 7)
# Test Accuracy of    N5: 50% ( 2/ 4)
# Test Accuracy of    O1: 100% ( 6/ 6)
# Test Accuracy of   O28: 100% ( 4/ 4)
# Test Accuracy of   O31: 71% ( 5/ 7)
# Test Accuracy of   O34: 100% ( 6/ 6)
# Test Accuracy of    O4: 100% ( 6/ 6)
# Test Accuracy of   O49: 100% ( 6/ 6)
# Test Accuracy of   O50: 85% ( 6/ 7)
# Test Accuracy of    P1: 87% ( 7/ 8)
# Test Accuracy of    P6: 100% ( 2/ 2)
# Test Accuracy of    P8: 80% ( 4/ 5)
# Test Accuracy of   P98: 100% ( 4/ 4)
# Test Accuracy of    Q1: 80% ( 4/ 5)
# Test Accuracy of    Q3: 100% ( 4/ 4)
# Test Accuracy of    Q7:  0% ( 0/ 7)
# Test Accuracy of    R4: 100% ( 8/ 8)
# Test Accuracy of    R8: 100% ( 6/ 6)
# Test Accuracy of   S24: 66% ( 4/ 6)
# Test Accuracy of   S28: 100% ( 5/ 5)
# Test Accuracy of   S29: 90% ( 9/10)
# Test Accuracy of   S34: 100% ( 9/ 9)
# Test Accuracy of   T20: 100% ( 5/ 5)
# Test Accuracy of   T21: 100% ( 1/ 1)
# Test Accuracy of   T22: 83% ( 5/ 6)
# Test Accuracy of   T28: 33% ( 2/ 6)
# Test Accuracy of   T30:  0% ( 0/ 5)
# Test Accuracy of    U1: 83% ( 5/ 6)
# Test Accuracy of   U15: 100% ( 3/ 3)
# Test Accuracy of   U28:  0% ( 0/ 3)
# Test Accuracy of   U33: 60% ( 3/ 5)
# Test Accuracy of    U7: 100% (11/11)
# Test Accuracy of   V13: 100% ( 6/ 6)
# Test Accuracy of   V24: 100% ( 7/ 7)
# Test Accuracy of   V28: 100% (11/11)
# Test Accuracy of   V30: 77% ( 7/ 9)
# Test Accuracy of   V31: 100% ( 4/ 4)
# Test Accuracy of    V4: 100% ( 7/ 7)
# Test Accuracy of    V6:  0% ( 0/ 7)
# Test Accuracy of    V7:  0% ( 0/ 8)
# Test Accuracy of   W11: 100% ( 9/ 9)
# Test Accuracy of   W18: 100% ( 8/ 8)
# Test Accuracy of   W19: 100% ( 9/ 9)
# Test Accuracy of   W22:  0% ( 0/13)
# Test Accuracy of   W24: 100% ( 1/ 1)
# Test Accuracy of   W25: 100% ( 8/ 8)
# Test Accuracy of    X1: 100% ( 7/ 7)
# Test Accuracy of    X8: 16% ( 2/12)
# Test Accuracy of    Y2:  0% ( 0/ 6)
# Test Accuracy of    Y3: 100% ( 7/ 7)
# Test Accuracy of    Y5: 100% ( 6/ 6)
# Test Accuracy of    Z1: 100% ( 4/ 4)
# Test Accuracy of   Z11: 83% ( 5/ 6)
# Test Accuracy of    Z7: 100% ( 5/ 5)
#
# Accuracy: 76.905%
#
# Precision: 77.084%
#
# Recall: 76.905%
#
# F1-score: 74.526%
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
