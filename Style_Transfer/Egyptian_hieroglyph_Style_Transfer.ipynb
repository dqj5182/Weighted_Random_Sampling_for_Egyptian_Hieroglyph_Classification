# %%
# %matplotlib inline

# %% [markdown]
# Neural Transfer Using PyTorch
# =============================
#
#
# **Author**: `Alexis Jacq <https://alexis-jacq.github.io>`_
#
# **Edited by**: `Winston Herring <https://github.com/winston6>`_
#
# Introduction
# ------------
#
# This tutorial explains how to implement the `Neural-Style algorithm <https://arxiv.org/abs/1508.06576>`__
# developed by Leon A. Gatys, Alexander S. Ecker and Matthias Bethge.
# Neural-Style, or Neural-Transfer, allows you to take an image and
# reproduce it with a new artistic style. The algorithm takes three images,
# an input image, a content-image, and a style-image, and changes the input
# to resemble the content of the content-image and the artistic style of the style-image.
#
#
# .. figure:: /_static/img/neural-style/neuralstyle.png
#    :alt: content1

# %% [markdown]
# Underlying Principle
# --------------------
#
# The principle is simple: we define two distances, one for the content
# ($D_C$) and one for the style ($D_S$). $D_C$ measures how different the content
# is between two images while $D_S$ measures how different the style is
# between two images. Then, we take a third image, the input, and
# transform it to minimize both its content-distance with the
# content-image and its style-distance with the style-image. Now we can
# import the necessary packages and begin the neural transfer.
#
# Importing Packages and Selecting a Device
# -----------------------------------------
# Below is a  list of the packages needed to implement the neural transfer.
#
# -  ``torch``, ``torch.nn``, ``numpy`` (indispensables packages for
#    neural networks with PyTorch)
# -  ``torch.optim`` (efficient gradient descents)
# -  ``PIL``, ``PIL.Image``, ``matplotlib.pyplot`` (load and display
#    images)
# -  ``torchvision.transforms`` (transform PIL images into tensors)
# -  ``torchvision.models`` (train or load pre-trained models)
# -  ``copy`` (to deep copy the models; system package)

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
import torchvision.models as models

import copy

# %% [markdown]
# Next, we need to choose which device to run the network on and import the
# content and style images. Running the neural transfer algorithm on large
# images takes longer and will go much faster when running on a GPU. We can
# use ``torch.cuda.is_available()`` to detect if there is a GPU available.
# Next, we set the ``torch.device`` for use throughout the tutorial. Also the ``.to(device)``
# method is used to move tensors or modules to a desired device.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading the Images
# ------------------
#
# Now we will import the style and content images. The original PIL images have values between 0 and 255, but when
# transformed into torch tensors, their values are converted to be between
# 0 and 1. The images also need to be resized to have the same dimensions.
# An important detail to note is that neural networks from the
# torch library are trained with tensor values ranging from 0 to 1. If you
# try to feed the networks with 0 to 255 tensor images, then the activated
# feature maps will be unable to sense the intended content and style.
# However, pre-trained networks from the Caffe library are trained with 0
# to 255 tensor images.
#
#
# .. Note::
#     Here are links to download the images required to run the tutorial:
#     `picasso.jpg <https://pytorch.org/tutorials/_static/img/neural-style/picasso.jpg>`__ and
#     `dancing.jpg <https://pytorch.org/tutorials/_static/img/neural-style/dancing.jpg>`__.
#     Download these two images and add them to a directory
#     with name ``images`` in your current working directory.

# %%
# Connecting and Mounting to the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def add_margin(pil_img, new_width, new_height, color):
    #pil_img = Image.open(img)
    width, height = pil_img.size # Get width and height of input image
    
    result = Image.new(pil_img.mode, (new_width, new_height), color)
    result.paste(pil_img, (int(new_width/2)-int(width/2), int(new_height/2)-int(height/2)))
    
    return result

# %%
# desired size of the output image
imsize = 100  # use small size if no gpu

loader = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((imsize, imsize)),  # scale imported image
    transforms.ToTensor()])  # transform it into a torch tensor


def image_loader(image_name):
    #image = Image.open(image_name)
    print(loader(image_name).size())
    # fake batch dimension required to fit network's input dimensions
    image = loader(image_name).unsqueeze(0)
    return image.to(device, torch.float)


style_img = image_loader(Image.open("/content/drive/MyDrive/EgyptianHieroglyphDataset_Original_Clean/train/D21/030163_D21.png"))

# Make transparent backgound into white background
image = Image.open("/content/drive/MyDrive/hiero_D23.png").convert("RGBA")
new_image = Image.new("RGBA", image.size, "WHITE") # Create a white rgba background
new_image.paste(image, (0, 0), image)

content_img = image_loader(add_margin(new_image, 100, 100, (255, 255, 255)))

assert style_img.size() == content_img.size(), \
    "we need to import style and content images of the same size"
# Out:
# torch.Size([3, 100, 100])
# torch.Size([3, 100, 100])

# %% [markdown]
# Now, let's create a function that displays an image by reconverting a
# copy of it to PIL format and displaying the copy using
# ``plt.imshow``. We will try displaying the content and style images
# to ensure they were imported correctly.

# %%
unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated


plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %% [markdown]
# Loss Functions
# --------------
# Content Loss
# ~~~~~~~~~~~~
#
# The content loss is a function that represents a weighted version of the
# content distance for an individual layer. The function takes the feature
# maps $F_{XL}$ of a layer $L$ in a network processing input $X$ and returns the
# weighted content distance $w_{CL}.D_C^L(X,C)$ between the image $X$ and the
# content image $C$. The feature maps of the content image($F_{CL}$) must be
# known by the function in order to calculate the content distance. We
# implement this function as a torch module with a constructor that takes
# $F_{CL}$ as an input. The distance $\|F_{XL} - F_{CL}\|^2$ is the mean square error
# between the two sets of feature maps, and can be computed using ``nn.MSELoss``.
#
# We will add this content loss module directly after the convolution
# layer(s) that are being used to compute the content distance. This way
# each time the network is fed an input image the content losses will be
# computed at the desired layers and because of auto grad, all the
# gradients will be computed. Now, in order to make the content loss layer
# transparent we must define a ``forward`` method that computes the content
# loss and then returns the layer’s input. The computed loss is saved as a
# parameter of the module.

# %%
class ContentLoss(nn.Module):

    def __init__(self, target,):
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.target = target.detach()

    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input

# %% [markdown]
# .. Note::
#    **Important detail**: although this module is named ``ContentLoss``, it
#    is not a true PyTorch Loss function. If you want to define your content
#    loss as a PyTorch Loss function, you have to create a PyTorch autograd function
#    to recompute/implement the gradient manually in the ``backward``
#    method.

# %% [markdown]
# Style Loss
# ~~~~~~~~~~
#
# The style loss module is implemented similarly to the content loss
# module. It will act as a transparent layer in a
# network that computes the style loss of that layer. In order to
# calculate the style loss, we need to compute the gram matrix $G_{XL}$. A gram
# matrix is the result of multiplying a given matrix by its transposed
# matrix. In this application the given matrix is a reshaped version of
# the feature maps $F_{XL}$ of a layer $L$. $F_{XL}$ is reshaped to form $\hat{F}_{XL}$, a $K$\ x\ $N$
# matrix, where $K$ is the number of feature maps at layer $L$ and $N$ is the
# length of any vectorized feature map $F_{XL}^k$. For example, the first line
# of $\hat{F}_{XL}$ corresponds to the first vectorized feature map $F_{XL}^1$.
#
# Finally, the gram matrix must be normalized by dividing each element by
# the total number of elements in the matrix. This normalization is to
# counteract the fact that $\hat{F}_{XL}$ matrices with a large $N$ dimension yield
# larger values in the Gram matrix. These larger values will cause the
# first layers (before pooling layers) to have a larger impact during the
# gradient descent. Style features tend to be in the deeper layers of the
# network so this normalization step is crucial.

# %%
def gram_matrix(input):
    a, b, c, d = input.size()  # a=batch size(=1)
    # b=number of feature maps
    # (c,d)=dimensions of a f. map (N=c*d)

    features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL

    G = torch.mm(features, features.t())  # compute the gram product

    # we 'normalize' the values of the gram matrix
    # by dividing by the number of element in each feature maps.
    return G.div(a * b * c * d)

# %% [markdown]
# Now the style loss module looks almost exactly like the content loss
# module. The style distance is also computed using the mean square
# error between $G_{XL}$ and $G_{SL}$.

# %%
class StyleLoss(nn.Module):

    def __init__(self, target_feature):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %% [markdown]
# Importing the Model
# -------------------
#
# Now we need to import a pre-trained neural network. We will use a 19
# layer VGG network like the one used in the paper.
#
# PyTorch’s implementation of VGG is a module divided into two child
# ``Sequential`` modules: ``features`` (containing convolution and pooling layers),
# and ``classifier`` (containing fully connected layers). We will use the
# ``features`` module because we need the output of the individual
# convolution layers to measure content and style loss. Some layers have
# different behavior during training than evaluation, so we must set the
# network to evaluation mode using ``.eval()``.

# %%
cnn = models.vgg19(pretrained=True).features.to(device).eval()

# %% [markdown]
# Additionally, VGG networks are trained on images with each channel
# normalized by mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225].
# We will use them to normalize the image before sending it into the network.

# %%
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)

# create a module to normalize input image so we can easily put it in a
# nn.Sequential
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        # .view the mean and std to make them [C x 1 x 1] so that they can
        # directly work with image Tensor of shape [B x C x H x W].
        # B is batch size. C is number of channels. H is height and W is width.
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        # normalize img
        return (img - self.mean) / self.std

# %% [markdown]
# A ``Sequential`` module contains an ordered list of child modules. For
# instance, ``vgg19.features`` contains a sequence (Conv2d, ReLU, MaxPool2d,
# Conv2d, ReLU…) aligned in the right order of depth. We need to add our
# content loss and style loss layers immediately after the convolution
# layer they are detecting. To do this we must create a new ``Sequential``
# module that has content loss and style loss modules correctly inserted.

# %%
# desired depth layers to compute style/content losses :
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    # normalization module
    normalization = Normalization(normalization_mean, normalization_std).to(device)

    # just in order to have an iterable access to or list of content/syle
    # losses
    content_losses = []
    style_losses = []

    # assuming that cnn is a nn.Sequential, so we make a new nn.Sequential
    # to put in modules that are supposed to be activated sequentially
    model = nn.Sequential(normalization)

    i = 0  # increment every time we see a conv
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ContentLoss
            # and StyleLoss we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)

        if name in content_layers:
            # add content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # add style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # now we trim off the layers after the last content and style losses
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

# %% [markdown]
# Next, we select the input image. You can use a copy of the content image
# or white noise.

# %%
input_img = content_img.clone()
# if you want to use white noise instead uncomment the below line:
# input_img = torch.randn(content_img.data.size(), device=device)

# add the original input image to the figure:
plt.figure()
imshow(input_img, title='Input Image')

# %% [markdown]
# Gradient Descent
# ----------------
#
# As Leon Gatys, the author of the algorithm, suggested `here <https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq>`__, we will use
# L-BFGS algorithm to run our gradient descent. Unlike training a network,
# we want to train the input image in order to minimise the content/style
# losses. We will create a PyTorch L-BFGS optimizer ``optim.LBFGS`` and pass
# our image to it as the tensor to optimize.

# %%
def get_input_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    optimizer = optim.LBFGS([input_img])
    return optimizer

# %% [markdown]
# Finally, we must define a function that performs the neural transfer. For
# each iteration of the networks, it is fed an updated input and computes
# new losses. We will run the ``backward`` methods of each loss module to
# dynamicaly compute their gradients. The optimizer requires a “closure”
# function, which reevaluates the module and returns the loss.
#
# We still have one final constraint to address. The network may try to
# optimize the input with values that exceed the 0 to 1 tensor range for
# the image. We can address this by correcting the input values to be
# between 0 to 1 each time the network is run.

# %%
def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=50000,
                       style_weight=5000000, content_weight=1): # Lower style weight preserve content
    """Run the style transfer."""
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)

    # We want to optimize the input and not the model parameters so we
    # update all the requires_grad fields accordingly
    input_img.requires_grad_(True)
    model.requires_grad_(False)

    optimizer = get_input_optimizer(input_img)

    print('Optimizing..')
    run = [0]
    while run[0] <= num_steps:

        def closure():
            # correct the values of updated input image
            with torch.no_grad():
                input_img.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss

            style_score *= style_weight
            content_score *= content_weight

            loss = style_score + content_score
            loss.backward()

            run[0] += 1
            if run[0] % 50 == 0:
                print("run {}:".format(run))
                print('Style Loss : {:4f} Content Loss: {:4f}'.format(
                    style_score.item(), content_score.item()))
                print()

            return style_score + content_score

        optimizer.step(closure)

    # a last correction...
    with torch.no_grad():
        input_img.clamp_(0, 1)

    return input_img

# %% [markdown]
# Finally, we can run the algorithm.

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img)

plt.figure()
imshow(output, title='Output Image')

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()
# Out:
# Building the style transfer model..
# Optimizing..
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# run [50]:
# Style Loss : 528.027588 Content Loss: 28.498018
#
# run [100]:
# Style Loss : 162.539642 Content Loss: 27.597075
#
# run [150]:
# Style Loss : 87.968712 Content Loss: 25.972008
#
# run [200]:
# Style Loss : 39.799881 Content Loss: 24.190926
#
# run [250]:
# Style Loss : 11.055822 Content Loss: 22.874874
#
# run [300]:
# Style Loss : 5.112761 Content Loss: 21.880198
#
# run [350]:
# Style Loss : 3.476539 Content Loss: 21.120518
#
# run [400]:
# Style Loss : 2.679078 Content Loss: 20.628895
#
# run [450]:
# Style Loss : 2.232865 Content Loss: 20.328451
#
# run [500]:
# Style Loss : 1.953312 Content Loss: 20.142603
#
# run [550]:
# Style Loss : 1.784552 Content Loss: 20.027208
#
# run [600]:
# Style Loss : 1.668957 Content Loss: 19.951857
#
# run [650]:
# Style Loss : 1.585454 Content Loss: 19.897127
#
# run [700]:
# Style Loss : 1.527003 Content Loss: 19.843960
#
# run [750]:
# Style Loss : 1.476404 Content Loss: 19.808163
#
# run [800]:
# Style Loss : 1.442278 Content Loss: 19.783836
#
# run [850]:
# Style Loss : 1.416757 Content Loss: 19.764254
#
# run [900]:
# Style Loss : 1.398285 Content Loss: 19.746664
#
# run [950]:
# Style Loss : 1.384662 Content Loss: 19.729383
#
# run [1000]:
# Style Loss : 1.374760 Content Loss: 19.712524
#
# run [1050]:
# Style Loss : 1.365831 Content Loss: 19.697235
#
# run [1100]:
# Style Loss : 1.356562 Content Loss: 19.685167
#
# run [1150]:
# Style Loss : 1.345438 Content Loss: 19.677469
#
# run [1200]:
# Style Loss : 1.337016 Content Loss: 19.669771
#
# run [1250]:
# Style Loss : 1.330006 Content Loss: 19.663181
#
# run [1300]:
# Style Loss : 1.323100 Content Loss: 19.656309
#
# run [1350]:
# Style Loss : 1.315876 Content Loss: 19.650640
#
# run [1400]:
# Style Loss : 1.309752 Content Loss: 19.644255
#
# run [1450]:
# Style Loss : 1.304431 Content Loss: 19.636841
#
# run [1500]:
# Style Loss : 1.299123 Content Loss: 19.631454
#
# run [1550]:
# Style Loss : 1.294211 Content Loss: 19.627596
#
# run [1600]:
# Style Loss : 1.290667 Content Loss: 19.623732
#
# run [1650]:
# Style Loss : 1.288044 Content Loss: 19.619696
#
# run [1700]:
# Style Loss : 1.286104 Content Loss: 19.615391
#
# run [1750]:
# Style Loss : 1.281182 Content Loss: 19.613634
#
# run [1800]:
# Style Loss : 1.277986 Content Loss: 19.611023
#
# run [1850]:
# Style Loss : 1.275800 Content Loss: 19.608362
#
# run [1900]:
# Style Loss : 1.273581 Content Loss: 19.606140
#
# run [1950]:
# Style Loss : 1.271063 Content Loss: 19.603865
#
# run [2000]:
# Style Loss : 1.268907 Content Loss: 19.600872
#
# run [2050]:
# Style Loss : 1.264846 Content Loss: 19.599699
#
# run [2100]:
# Style Loss : 1.261744 Content Loss: 19.598118
#
# run [2150]:
# Style Loss : 1.259697 Content Loss: 19.595844
#
# run [2200]:
# Style Loss : 1.258008 Content Loss: 19.594053
#
# run [2250]:
# Style Loss : 1.256224 Content Loss: 19.592783
#
# run [2300]:
# Style Loss : 1.255241 Content Loss: 19.590460
#
# run [2350]:
# Style Loss : 1.253650 Content Loss: 19.588762
#
# run [2400]:
# Style Loss : 1.251501 Content Loss: 19.587875
#
# run [2450]:
# Style Loss : 1.249176 Content Loss: 19.587234
#
# run [2500]:
# Style Loss : 1.246796 Content Loss: 19.586601
#
# run [2550]:
# Style Loss : 1.244847 Content Loss: 19.585577
#
# run [2600]:
# Style Loss : 1.243116 Content Loss: 19.584530
#
# run [2650]:
# Style Loss : 1.241530 Content Loss: 19.583639
#
# run [2700]:
# Style Loss : 1.240482 Content Loss: 19.582272
#
# run [2750]:
# Style Loss : 1.239983 Content Loss: 19.580606
#
# run [2800]:
# Style Loss : 1.238788 Content Loss: 19.579872
#
# run [2850]:
# Style Loss : 1.237093 Content Loss: 19.579609
#
# run [2900]:
# Style Loss : 1.236103 Content Loss: 19.578800
#
# run [2950]:
# Style Loss : 1.235111 Content Loss: 19.578051
#
# run [3000]:
# Style Loss : 1.234619 Content Loss: 19.576809
#
# run [3050]:
# Style Loss : 1.234366 Content Loss: 19.575422
#
# run [3100]:
# Style Loss : 1.234048 Content Loss: 19.574150
#
# run [3150]:
# Style Loss : 1.233285 Content Loss: 19.573372
#
# run [3200]:
# Style Loss : 1.232764 Content Loss: 19.572384
#
# run [3250]:
# Style Loss : 1.232264 Content Loss: 19.571112
#
# run [3300]:
# Style Loss : 1.231316 Content Loss: 19.570240
#
# run [3350]:
# Style Loss : 1.229705 Content Loss: 19.569984
#
# run [3400]:
# Style Loss : 1.229192 Content Loss: 19.568802
#
# run [3450]:
# Style Loss : 1.228187 Content Loss: 19.568422
#
# run [3500]:
# Style Loss : 1.227088 Content Loss: 19.568048
#
# run [3550]:
# Style Loss : 1.226095 Content Loss: 19.567513
#
# run [3600]:
# Style Loss : 1.225166 Content Loss: 19.567091
#
# run [3650]:
# Style Loss : 1.223928 Content Loss: 19.567049
#
# run [3700]:
# Style Loss : 1.223305 Content Loss: 19.566416
#
# run [3750]:
# Style Loss : 1.222837 Content Loss: 19.565651
#
# run [3800]:
# Style Loss : 1.222215 Content Loss: 19.565115
#
# run [3850]:
# Style Loss : 1.221475 Content Loss: 19.564779
#
# run [3900]:
# Style Loss : 1.220979 Content Loss: 19.564182
#
# run [3950]:
# Style Loss : 1.219898 Content Loss: 19.564127
#
# run [4000]:
# Style Loss : 1.219186 Content Loss: 19.563660
#
# run [4050]:
# Style Loss : 1.218621 Content Loss: 19.563128
#
# run [4100]:
# Style Loss : 1.218146 Content Loss: 19.562637
#
# run [4150]:
# Style Loss : 1.217947 Content Loss: 19.561943
#
# run [4200]:
# Style Loss : 1.217621 Content Loss: 19.561342
#
# run [4250]:
# Style Loss : 1.216877 Content Loss: 19.561243
#
# run [4300]:
# Style Loss : 1.216213 Content Loss: 19.560934
#
# run [4350]:
# Style Loss : 1.215753 Content Loss: 19.560377
#
# run [4400]:
# Style Loss : 1.215271 Content Loss: 19.559929
#
# run [4450]:
# Style Loss : 1.215536 Content Loss: 19.558727
#
# run [4500]:
# Style Loss : 1.215441 Content Loss: 19.557909
#
# run [4550]:
# Style Loss : 1.215111 Content Loss: 19.557350
#
# run [4600]:
# Style Loss : 1.214698 Content Loss: 19.556837
#
# run [4650]:
# Style Loss : 1.214114 Content Loss: 19.556652
#
# run [4700]:
# Style Loss : 1.213597 Content Loss: 19.556446
#
# run [4750]:
# Style Loss : 1.213172 Content Loss: 19.556063
#
# run [4800]:
# Style Loss : 1.212605 Content Loss: 19.555609
#
# run [4850]:
# Style Loss : 1.212129 Content Loss: 19.555054
#
# run [4900]:
# Style Loss : 1.211293 Content Loss: 19.554932
#
# run [4950]:
# Style Loss : 1.210676 Content Loss: 19.554594
#
# run [5000]:
# Style Loss : 1.209906 Content Loss: 19.554493
#
# run [5050]:
# Style Loss : 1.209419 Content Loss: 19.554161
#
# run [5100]:
# Style Loss : 1.209005 Content Loss: 19.553829
#
# run [5150]:
# Style Loss : 1.208842 Content Loss: 19.553352
#
# run [5200]:
# Style Loss : 1.208854 Content Loss: 19.552744
#
# run [5250]:
# Style Loss : 1.208742 Content Loss: 19.552219
#
# run [5300]:
# Style Loss : 1.208630 Content Loss: 19.551737
#
# run [5350]:
# Style Loss : 1.208210 Content Loss: 19.551556
#
# run [5400]:
# Style Loss : 1.207888 Content Loss: 19.551266
#
# run [5450]:
# Style Loss : 1.207697 Content Loss: 19.550871
#
# run [5500]:
# Style Loss : 1.207711 Content Loss: 19.550327
#
# run [5550]:
# Style Loss : 1.207690 Content Loss: 19.549831
#
# run [5600]:
# Style Loss : 1.207740 Content Loss: 19.549236
#
# run [5650]:
# Style Loss : 1.207606 Content Loss: 19.548820
#
# run [5700]:
# Style Loss : 1.207390 Content Loss: 19.548492
#
# run [5750]:
# Style Loss : 1.207202 Content Loss: 19.548195
#
# run [5800]:
# Style Loss : 1.207415 Content Loss: 19.547495
#
# run [5850]:
# Style Loss : 1.207836 Content Loss: 19.546555
#
# run [5900]:
# Style Loss : 1.208041 Content Loss: 19.545866
#
# run [5950]:
# Style Loss : 1.207857 Content Loss: 19.545630
#
# run [6000]:
# Style Loss : 1.207203 Content Loss: 19.545864
#
# run [6050]:
# Style Loss : 1.207051 Content Loss: 19.545563
#
# run [6100]:
# Style Loss : 1.207164 Content Loss: 19.544937
#
# run [6150]:
# Style Loss : 1.206867 Content Loss: 19.544703
#
# run [6200]:
# Style Loss : 1.206340 Content Loss: 19.544662
#
# run [6250]:
# Style Loss : 1.206344 Content Loss: 19.544037
#
# run [6300]:
# Style Loss : 1.206117 Content Loss: 19.543575
#
# run [6350]:
# Style Loss : 1.205416 Content Loss: 19.543478
#
# run [6400]:
# Style Loss : 1.204728 Content Loss: 19.543390
#
# run [6450]:
# Style Loss : 1.203922 Content Loss: 19.543688
#
# run [6500]:
# Style Loss : 1.203348 Content Loss: 19.543781
#
# run [6550]:
# Style Loss : 1.202743 Content Loss: 19.543879
#
# run [6600]:
# Style Loss : 1.202608 Content Loss: 19.543434
#
# run [6650]:
# Style Loss : 1.202345 Content Loss: 19.543015
#
# run [6700]:
# Style Loss : 1.202310 Content Loss: 19.542385
#
# run [6750]:
# Style Loss : 1.202151 Content Loss: 19.541895
#
# run [6800]:
# Style Loss : 1.201660 Content Loss: 19.541956
#
# run [6850]:
# Style Loss : 1.201350 Content Loss: 19.541910
#
# run [6900]:
# Style Loss : 1.201160 Content Loss: 19.541702
#
# run [6950]:
# Style Loss : 1.201024 Content Loss: 19.541487
#
# run [7000]:
# Style Loss : 1.200932 Content Loss: 19.541199
#
# run [7050]:
# Style Loss : 1.200935 Content Loss: 19.540812
#
# run [7100]:
# Style Loss : 1.200755 Content Loss: 19.540577
#
# run [7150]:
# Style Loss : 1.200588 Content Loss: 19.540369
#
# run [7200]:
# Style Loss : 1.200642 Content Loss: 19.539927
#
# run [7250]:
# Style Loss : 1.200570 Content Loss: 19.539618
#
# run [7300]:
# Style Loss : 1.200191 Content Loss: 19.539522
#
# run [7350]:
# Style Loss : 1.200021 Content Loss: 19.539328
#
# run [7400]:
# Style Loss : 1.199943 Content Loss: 19.538921
#
# run [7450]:
# Style Loss : 1.199863 Content Loss: 19.538540
#
# run [7500]:
# Style Loss : 1.199772 Content Loss: 19.538294
#
# run [7550]:
# Style Loss : 1.199725 Content Loss: 19.538031
#
# run [7600]:
# Style Loss : 1.199629 Content Loss: 19.537821
#
# run [7650]:
# Style Loss : 1.199215 Content Loss: 19.537878
#
# run [7700]:
# Style Loss : 1.198700 Content Loss: 19.538036
#
# run [7750]:
# Style Loss : 1.198690 Content Loss: 19.537689
#
# run [7800]:
# Style Loss : 1.198787 Content Loss: 19.537262
#
# run [7850]:
# Style Loss : 1.198701 Content Loss: 19.537016
#
# run [7900]:
# Style Loss : 1.198717 Content Loss: 19.536652
#
# run [7950]:
# Style Loss : 1.198709 Content Loss: 19.536324
#
# run [8000]:
# Style Loss : 1.198472 Content Loss: 19.536255
#
# run [8050]:
# Style Loss : 1.198287 Content Loss: 19.536127
#
# run [8100]:
# Style Loss : 1.198239 Content Loss: 19.535837
#
# run [8150]:
# Style Loss : 1.198193 Content Loss: 19.535528
#
# run [8200]:
# Style Loss : 1.198176 Content Loss: 19.535175
#
# run [8250]:
# Style Loss : 1.197955 Content Loss: 19.534977
#
# run [8300]:
# Style Loss : 1.197783 Content Loss: 19.534735
#
# run [8350]:
# Style Loss : 1.197977 Content Loss: 19.534105
#
# run [8400]:
# Style Loss : 1.198081 Content Loss: 19.533577
#
# run [8450]:
# Style Loss : 1.198349 Content Loss: 19.532906
#
# run [8500]:
# Style Loss : 1.198297 Content Loss: 19.532537
#
# run [8550]:
# Style Loss : 1.198363 Content Loss: 19.532063
#
# run [8600]:
# Style Loss : 1.198555 Content Loss: 19.531519
#
# run [8650]:
# Style Loss : 1.198598 Content Loss: 19.531139
#
# run [8700]:
# Style Loss : 1.198510 Content Loss: 19.530886
#
# run [8750]:
# Style Loss : 1.198402 Content Loss: 19.530668
#
# run [8800]:
# Style Loss : 1.198255 Content Loss: 19.530537
#
# run [8850]:
# Style Loss : 1.198268 Content Loss: 19.530266
#
# run [8900]:
# Style Loss : 1.198234 Content Loss: 19.530077
#
# run [8950]:
# Style Loss : 1.198119 Content Loss: 19.529984
#
# run [9000]:
# Style Loss : 1.198032 Content Loss: 19.529850
#
# run [9050]:
# Style Loss : 1.197825 Content Loss: 19.529799
#
# run [9100]:
# Style Loss : 1.197600 Content Loss: 19.529755
#
# run [9150]:
# Style Loss : 1.197361 Content Loss: 19.529737
#
# run [9200]:
# Style Loss : 1.197148 Content Loss: 19.529713
#
# run [9250]:
# Style Loss : 1.196869 Content Loss: 19.529724
#
# run [9300]:
# Style Loss : 1.196600 Content Loss: 19.529703
#
# run [9350]:
# Style Loss : 1.196469 Content Loss: 19.529541
#
# run [9400]:
# Style Loss : 1.196485 Content Loss: 19.529264
#
# run [9450]:
# Style Loss : 1.196541 Content Loss: 19.528986
#
# run [9500]:
# Style Loss : 1.196415 Content Loss: 19.528887
#
# run [9550]:
# Style Loss : 1.196294 Content Loss: 19.528782
#
# run [9600]:
# Style Loss : 1.196342 Content Loss: 19.528528
#
# run [9650]:
# Style Loss : 1.196276 Content Loss: 19.528387
#
# run [9700]:
# Style Loss : 1.196102 Content Loss: 19.528343
#
# run [9750]:
# Style Loss : 1.196035 Content Loss: 19.528200
#
# run [9800]:
# Style Loss : 1.195957 Content Loss: 19.528074
#
# run [9850]:
# Style Loss : 1.195871 Content Loss: 19.527967
#
# run [9900]:
# Style Loss : 1.195824 Content Loss: 19.527849
#
# run [9950]:
# Style Loss : 1.195841 Content Loss: 19.527639
#
# run [10000]:
# Style Loss : 1.195706 Content Loss: 19.527580
#
# run [10050]:
# Style Loss : 1.195513 Content Loss: 19.527559
#
# run [10100]:
# Style Loss : 1.195482 Content Loss: 19.527370
#
# run [10150]:
# Style Loss : 1.195354 Content Loss: 19.527283
#
# run [10200]:
# Style Loss : 1.195210 Content Loss: 19.527231
#
# run [10250]:
# Style Loss : 1.194993 Content Loss: 19.527241
#
# run [10300]:
# Style Loss : 1.194805 Content Loss: 19.527206
#
# run [10350]:
# Style Loss : 1.194627 Content Loss: 19.527140
#
# run [10400]:
# Style Loss : 1.194493 Content Loss: 19.527039
#
# run [10450]:
# Style Loss : 1.194506 Content Loss: 19.526777
#
# run [10500]:
# Style Loss : 1.194394 Content Loss: 19.526644
#
# run [10550]:
# Style Loss : 1.194255 Content Loss: 19.526541
#
# run [10600]:
# Style Loss : 1.194160 Content Loss: 19.526415
#
# run [10650]:
# Style Loss : 1.194098 Content Loss: 19.526287
#
# run [10700]:
# Style Loss : 1.194042 Content Loss: 19.526155
#
# run [10750]:
# Style Loss : 1.194053 Content Loss: 19.525984
#
# run [10800]:
# Style Loss : 1.193995 Content Loss: 19.525892
#
# run [10850]:
# Style Loss : 1.193914 Content Loss: 19.525824
#
# run [10900]:
# Style Loss : 1.193748 Content Loss: 19.525871
#
# run [10950]:
# Style Loss : 1.193567 Content Loss: 19.525896
#
# run [11000]:
# Style Loss : 1.193348 Content Loss: 19.525967
#
# run [11050]:
# Style Loss : 1.193287 Content Loss: 19.525862
#
# run [11100]:
# Style Loss : 1.193314 Content Loss: 19.525677
#
# run [11150]:
# Style Loss : 1.188707 Content Loss: 19.516811
#
# run [15500]:
# Style Loss : 1.188674 Content Loss: 19.516733
#
# run [15550]:
# Style Loss : 1.188620 Content Loss: 19.516689
#
# run [15600]:
# Style Loss : 1.188629 Content Loss: 19.516594
#
# run [15650]:
# Style Loss : 1.188611 Content Loss: 19.516518
#
# run [15700]:
# Style Loss : 1.188619 Content Loss: 19.516417
#
# run [15750]:
# Style Loss : 1.188594 Content Loss: 19.516359
#
# run [15800]:
# Style Loss : 1.188539 Content Loss: 19.516333
#
# run [15850]:
# Style Loss : 1.188484 Content Loss: 19.516293
#
# run [15900]:
# Style Loss : 1.188449 Content Loss: 19.516249
#
# run [15950]:
# Style Loss : 1.188429 Content Loss: 19.516174
#
# run [16000]:
# Style Loss : 1.188431 Content Loss: 19.516056
#
# run [16050]:
# Style Loss : 1.188340 Content Loss: 19.516033
#
# run [16100]:
# Style Loss : 1.188193 Content Loss: 19.516047
#
# run [16150]:
# Style Loss : 1.188067 Content Loss: 19.516052
#
# run [16200]:
# Style Loss : 1.188014 Content Loss: 19.516012
#
# run [16250]:
# Style Loss : 1.187993 Content Loss: 19.515924
#
# run [16300]:
# Style Loss : 1.187989 Content Loss: 19.515795
#
# run [16350]:
# Style Loss : 1.187975 Content Loss: 19.515656
#
# run [16400]:
# Style Loss : 1.187903 Content Loss: 19.515602
#
# run [16450]:
# Style Loss : 1.187846 Content Loss: 19.515547
#
# run [16500]:
# Style Loss : 1.187799 Content Loss: 19.515478
#
# run [16550]:
# Style Loss : 1.187731 Content Loss: 19.515446
#
# run [16600]:
# Style Loss : 1.187597 Content Loss: 19.515482
#
# run [16650]:
# Style Loss : 1.187486 Content Loss: 19.515491
#
# run [16700]:
# Style Loss : 1.187374 Content Loss: 19.515501
#
# run [16750]:
# Style Loss : 1.187324 Content Loss: 19.515453
#
# run [16800]:
# Style Loss : 1.187297 Content Loss: 19.515392
#
# run [16850]:
# Style Loss : 1.187322 Content Loss: 19.515278
#
# run [16900]:
# Style Loss : 1.187339 Content Loss: 19.515171
#
# run [16950]:
# Style Loss : 1.187373 Content Loss: 19.515043
#
# run [17000]:
# Style Loss : 1.187369 Content Loss: 19.514969
#
# run [17050]:
# Style Loss : 1.187355 Content Loss: 19.514887
#
# run [17100]:
# Style Loss : 1.187317 Content Loss: 19.514833
#
# run [17150]:
# Style Loss : 1.187220 Content Loss: 19.514814
#
# run [17200]:
# Style Loss : 1.187183 Content Loss: 19.514740
#
# run [17250]:
# Style Loss : 1.187133 Content Loss: 19.514696
#
# run [17300]:
# Style Loss : 1.187086 Content Loss: 19.514650
#
# run [17350]:
# Style Loss : 1.187066 Content Loss: 19.514568
#
# run [17400]:
# Style Loss : 1.186983 Content Loss: 19.514553
#
# run [17450]:
# Style Loss : 1.186864 Content Loss: 19.514574
#
# run [17500]:
# Style Loss : 1.186787 Content Loss: 19.514544
#
# run [17550]:
# Style Loss : 1.186738 Content Loss: 19.514490
#
# run [17600]:
# Style Loss : 1.186721 Content Loss: 19.514389
# run [19800]:
# Style Loss : 1.183975 Content Loss: 19.512259
#
# run [19850]:
# Style Loss : 1.183964 Content Loss: 19.512230
#
# run [19900]:
# Style Loss : 1.183943 Content Loss: 19.512213
#
# run [19950]:
# Style Loss : 1.183897 Content Loss: 19.512215
#
# run [20000]:
# Style Loss : 1.183849 Content Loss: 19.512224
#
# run [20050]:
# Style Loss : 1.183789 Content Loss: 19.512243
#
# run [20100]:
# Style Loss : 1.183730 Content Loss: 19.512259
#
# run [20150]:
# Style Loss : 1.183676 Content Loss: 19.512278
#
# run [20200]:
# Style Loss : 1.183634 Content Loss: 19.512281
#
# run [20250]:
# Style Loss : 1.183601 Content Loss: 19.512272
#
# run [20300]:
# Style Loss : 1.183562 Content Loss: 19.512274
#
# run [20350]:
# Style Loss : 1.183539 Content Loss: 19.512259
#
# run [20400]:
# Style Loss : 1.183533 Content Loss: 19.512230
#
# run [20450]:
# Style Loss : 1.183525 Content Loss: 19.512205
#
# run [20500]:
# Style Loss : 1.183508 Content Loss: 19.512190
#
# run [20550]:
# Style Loss : 1.183495 Content Loss: 19.512173
#
# run [20600]:
# Style Loss : 1.183487 Content Loss: 19.512150
#
# run [20650]:
# Style Loss : 1.183457 Content Loss: 19.512144
#
# run [20700]:
# Style Loss : 1.183426 Content Loss: 19.512136
#
# run [20750]:
# Style Loss : 1.183400 Content Loss: 19.512125
#
# run [20800]:
# Style Loss : 1.183347 Content Loss: 19.512131
#
# run [20850]:
# Style Loss : 1.183303 Content Loss: 19.512133
#
# run [20900]:
# Style Loss : 1.183243 Content Loss: 19.512152
#
# run [20950]:
# Style Loss : 1.183165 Content Loss: 19.512188
#
# run [21000]:
# Style Loss : 1.183091 Content Loss: 19.512213
#
# run [21050]:
# Style Loss : 1.183056 Content Loss: 19.512203
#
# run [21100]:
# Style Loss : 1.183022 Content Loss: 19.512190
#
# run [21150]:
# Style Loss : 1.182969 Content Loss: 19.512199
#
# run [21200]:
# Style Loss : 1.182922 Content Loss: 19.512199
#
# run [21250]:
# Style Loss : 1.182871 Content Loss: 19.512209
#
# run [21300]:
# Style Loss : 1.182784 Content Loss: 19.512247
#
# run [21350]:
# Style Loss : 1.182701 Content Loss: 19.512287
#
# run [21400]:
# Style Loss : 1.182612 Content Loss: 19.512331
#
# run [21450]:
# Style Loss : 1.182536 Content Loss: 19.512360
#
# run [21500]:
# Style Loss : 1.182447 Content Loss: 19.512394
#
# run [21550]:
# Style Loss : 1.182382 Content Loss: 19.512398
#
# run [21600]:
# Style Loss : 1.182349 Content Loss: 19.512375
#
# run [21650]:
# Style Loss : 1.182288 Content Loss: 19.512379
#
# run [21700]:
# Style Loss : 1.182232 Content Loss: 19.512381
#
# run [21750]:
# Style Loss : 1.182191 Content Loss: 19.512371
#
# run [21800]:
# Style Loss : 1.182106 Content Loss: 19.512400
#
# run [21850]:
# Style Loss : 1.182032 Content Loss: 19.512421
#
# run [21900]:
# Style Loss : 1.181975 Content Loss: 19.512426
#
# run [21950]:
# Style Loss : 1.181916 Content Loss: 19.512438
#
# run [22000]:
# Style Loss : 1.181896 Content Loss: 19.512421
#
# run [22050]:
# Style Loss : 1.181890 Content Loss: 19.512386
#
# run [22100]:
# Style Loss : 1.181887 Content Loss: 19.512350
#
# run [22150]:
# Style Loss : 1.181885 Content Loss: 19.512302
#
# run [22200]:
# Style Loss : 1.181873 Content Loss: 19.512268
#
# run [22250]:
# Style Loss : 1.181830 Content Loss: 19.512257
#
# run [22300]:
# Style Loss : 1.181787 Content Loss: 19.512243
#
# run [22350]:
# Style Loss : 1.181774 Content Loss: 19.512205
#
# run [22400]:
# Style Loss : 1.181724 Content Loss: 19.512199
#
# run [22450]:
# Style Loss : 1.181707 Content Loss: 19.512161
#
# run [22500]:
# Style Loss : 1.181696 Content Loss: 19.512125
#
# run [22550]:
# Style Loss : 1.181685 Content Loss: 19.512085
#
# run [22600]:
# Style Loss : 1.181661 Content Loss: 19.512058
#
# run [22650]:
# Style Loss : 1.181634 Content Loss: 19.512033
#
# run [22700]:
# Style Loss : 1.181606 Content Loss: 19.512012
#
# run [22750]:
# Style Loss : 1.181581 Content Loss: 19.511997
#
# run [22800]:
# Style Loss : 1.181550 Content Loss: 19.511984
#
# run [22850]:
# Style Loss : 1.181504 Content Loss: 19.511980
#
# run [22900]:
# Style Loss : 1.181478 Content Loss: 19.511959
#
# run [22950]:
# Style Loss : 1.181452 Content Loss: 19.511936
#
# run [23000]:
# Style Loss : 1.181413 Content Loss: 19.511919
#
# run [23050]:
# Style Loss : 1.181364 Content Loss: 19.511902
#
# run [23100]:
# Style Loss : 1.181321 Content Loss: 19.511877
#
# run [23150]:
# Style Loss : 1.181272 Content Loss: 19.511868
#
# run [23200]:
# Style Loss : 1.181195 Content Loss: 19.511881
#
# run [23250]:
# Style Loss : 1.181127 Content Loss: 19.511892
#
# run [23300]:
# Style Loss : 1.181077 Content Loss: 19.511883
#
# run [23350]:
# Style Loss : 1.181036 Content Loss: 19.511866
#
# run [23400]:
# Style Loss : 1.181007 Content Loss: 19.511841
#
# run [23450]:
# Style Loss : 1.180980 Content Loss: 19.511816
#
# run [23500]:
# Style Loss : 1.180956 Content Loss: 19.511787
#
# run [23550]:
# Style Loss : 1.180910 Content Loss: 19.511768
#
# run [23600]:
# Style Loss : 1.180882 Content Loss: 19.511738
#
# run [23650]:
# Style Loss : 1.180876 Content Loss: 19.511692
#
# run [23700]:
# Style Loss : 1.180879 Content Loss: 19.511627
#
# run [23750]:
# Style Loss : 1.180886 Content Loss: 19.511564
#
# run [23800]:
# Style Loss : 1.180895 Content Loss: 19.511505
#
# run [23850]:
# Style Loss : 1.180907 Content Loss: 19.511436
#
# run [23900]:
# Style Loss : 1.180908 Content Loss: 19.511383
#
# run [23950]:
# Style Loss : 1.180914 Content Loss: 19.511324
#
# run [24000]:
# Style Loss : 1.180882 Content Loss: 19.511305
#
# run [24050]:
# Style Loss : 1.180839 Content Loss: 19.511303
#
# run [24100]:
#
# run [28450]:
# Style Loss : 1.177496 Content Loss: 19.507772
#
# run [28500]:
# Style Loss : 1.177483 Content Loss: 19.507671
#
# run [28550]:
# Style Loss : 1.177433 Content Loss: 19.507616
#
# run [28600]:
# Style Loss : 1.177397 Content Loss: 19.507551
#
# run [28650]:
# Style Loss : 1.177383 Content Loss: 19.507469
#
# run [28700]:
# Style Loss : 1.177373 Content Loss: 19.507376
#
# run [28750]:
# Style Loss : 1.177370 Content Loss: 19.507288
#
# run [28800]:
# Style Loss : 1.177379 Content Loss: 19.507187
#
# run [28850]:
# Style Loss : 1.177344 Content Loss: 19.507128
#
# run [28900]:
# Style Loss : 1.177237 Content Loss: 19.507128
#
# run [28950]:
# Style Loss : 1.177105 Content Loss: 19.507153
#
# run [29000]:
# Style Loss : 1.177028 Content Loss: 19.507126
#
# run [29050]:
# Style Loss : 1.176930 Content Loss: 19.507132
#
# run [29100]:
# Style Loss : 1.176849 Content Loss: 19.507128
#
# run [29150]:
# Style Loss : 1.176796 Content Loss: 19.507078
#
# run [29200]:
# Style Loss : 1.176729 Content Loss: 19.507015
#
# run [29250]:
# Style Loss : 1.176599 Content Loss: 19.507002
#
# run [29300]:
# Style Loss : 1.176461 Content Loss: 19.507002
#
# run [29350]:
# Style Loss : 1.176309 Content Loss: 19.506990
#
# run [29400]:
# Style Loss : 1.176168 Content Loss: 19.507006
#
# run [29450]:
# Style Loss : 1.176116 Content Loss: 19.506952
#
# run [29500]:
# Style Loss : 1.176081 Content Loss: 19.506865
#
# run [29550]:
# Style Loss : 1.175911 Content Loss: 19.506828
#
# run [29600]:
# Style Loss : 1.175791 Content Loss: 19.506742
#
# run [29650]:
# Style Loss : 1.175711 Content Loss: 19.506603
#
# run [29700]:
# Style Loss : 1.175526 Content Loss: 19.506599
#
# run [29750]:
# Style Loss : 1.175348 Content Loss: 19.506636
#
# run [29800]:
# Style Loss : 1.175178 Content Loss: 19.506659
#
# run [29850]:
# Style Loss : 1.175004 Content Loss: 19.506670
#
# run [29900]:
# Style Loss : 1.174736 Content Loss: 19.506771
#
# run [29950]:
# Style Loss : 1.174389 Content Loss: 19.506933
#
# run [30000]:
# Style Loss : 1.174138 Content Loss: 19.506971
#
# run [30050]:
# Style Loss : 1.173870 Content Loss: 19.507006
#
# run [30100]:
# Style Loss : 1.173633 Content Loss: 19.507010
#
# run [30150]:
# Style Loss : 1.173556 Content Loss: 19.506880
#
# run [30200]:
# Style Loss : 1.173552 Content Loss: 19.506702
#
# run [30250]:
# Style Loss : 1.173495 Content Loss: 19.506598
#
# run [30300]:
# Style Loss : 1.173378 Content Loss: 19.506578
#
# run [30350]:
# Style Loss : 1.173334 Content Loss: 19.506510
#
# run [30400]:
# Style Loss : 1.173366 Content Loss: 19.506329
#
# run [30450]:
# Style Loss : 1.173410 Content Loss: 19.506138
#
# run [30500]:
# Style Loss : 1.173428 Content Loss: 19.505987
#
# run [30550]:
# Style Loss : 1.173466 Content Loss: 19.505835
#
# Style Loss : 1.171916 Content Loss: 19.504557
#
# run [32800]:
# Style Loss : 1.171882 Content Loss: 19.504549
#
# run [32850]:
# Style Loss : 1.171856 Content Loss: 19.504532
#
# run [32900]:
# Style Loss : 1.171823 Content Loss: 19.504526
#
# run [32950]:
# Style Loss : 1.171789 Content Loss: 19.504524
#
# run [33000]:
# Style Loss : 1.171767 Content Loss: 19.504513
#
# run [33050]:
# Style Loss : 1.171757 Content Loss: 19.504486
#
# run [33100]:
# Style Loss : 1.171746 Content Loss: 19.504465
#
# run [33150]:
# Style Loss : 1.171737 Content Loss: 19.504444
#
# run [33200]:
# Style Loss : 1.171740 Content Loss: 19.504400
#
# run [33250]:
# Style Loss : 1.171753 Content Loss: 19.504347
#
# run [33300]:
# Style Loss : 1.171792 Content Loss: 19.504263
#
# run [33350]:
# Style Loss : 1.171815 Content Loss: 19.504200
#
# run [33400]:
# Style Loss : 1.171816 Content Loss: 19.504162
#
# run [33450]:
# Style Loss : 1.171806 Content Loss: 19.504133
#
# run [33500]:
# Style Loss : 1.171798 Content Loss: 19.504097
#
# run [33550]:
# Style Loss : 1.171756 Content Loss: 19.504099
#
# run [33600]:
# Style Loss : 1.171694 Content Loss: 19.504112
#
# run [33650]:
# Style Loss : 1.171627 Content Loss: 19.504131
#
# run [33700]:
# Style Loss : 1.171567 Content Loss: 19.504143
#
# run [33750]:
# Style Loss : 1.171502 Content Loss: 19.504156
#
# run [33800]:
# Style Loss : 1.171454 Content Loss: 19.504158
#
# run [33850]:
# Style Loss : 1.171399 Content Loss: 19.504164
#
# run [33900]:
# Style Loss : 1.171347 Content Loss: 19.504168
#
# run [33950]:
# Style Loss : 1.171280 Content Loss: 19.504187
#
# run [34000]:
# Style Loss : 1.171251 Content Loss: 19.504175
#
# run [34050]:
# Style Loss : 1.171239 Content Loss: 19.504143
#
# run [34100]:
# Style Loss : 1.171225 Content Loss: 19.504120
#
# run [34150]:
# Style Loss : 1.171222 Content Loss: 19.504068
#
# run [34200]:
# Style Loss : 1.171212 Content Loss: 19.504030
#
# run [34250]:
# Style Loss : 1.171190 Content Loss: 19.504009
#
# run [34300]:
# Style Loss : 1.171159 Content Loss: 19.504000
#
# run [34350]:
# Style Loss : 1.171109 Content Loss: 19.503990
#
# run [34400]:
# Style Loss : 1.171089 Content Loss: 19.503963
#
# run [34450]:
# Style Loss : 1.171083 Content Loss: 19.503925
#
# run [34500]:
# Style Loss : 1.171096 Content Loss: 19.503866
#
# run [34550]:
# Style Loss : 1.171091 Content Loss: 19.503824
#
# run [34600]:
# Style Loss : 1.171072 Content Loss: 19.503799
#
# run [34650]:
# Style Loss : 1.171061 Content Loss: 19.503765
#
# run [34700]:
# Style Loss : 1.171058 Content Loss: 19.503727
#
# run [34750]:
# Style Loss : 1.171060 Content Loss: 19.503679
#
# run [34800]:
# Style Loss : 1.171065 Content Loss: 19.503622
#
# run [34850]:
# Style Loss : 1.171078 Content Loss: 19.503553
#
# run [34900]:
#
# run [37100]:
# Style Loss : 1.166938 Content Loss: 19.502493
#
# run [37150]:
# Style Loss : 1.166814 Content Loss: 19.502512
#
# run [37200]:
# Style Loss : 1.166651 Content Loss: 19.502575
#
# run [37250]:
# Style Loss : 1.166530 Content Loss: 19.502607
#
# run [37300]:
# Style Loss : 1.166365 Content Loss: 19.502689
#
# run [37350]:
# Style Loss : 1.166325 Content Loss: 19.502642
#
# run [37400]:
# Style Loss : 1.166316 Content Loss: 19.502575
#
# run [37450]:
# Style Loss : 1.166304 Content Loss: 19.502508
#
# run [37500]:
# Style Loss : 1.166256 Content Loss: 19.502474
#
# run [37550]:
# Style Loss : 1.166269 Content Loss: 19.502380
#
# run [37600]:
# Style Loss : 1.166239 Content Loss: 19.502337
#
# run [37650]:
# Style Loss : 1.166158 Content Loss: 19.502356
#
# run [37700]:
# Style Loss : 1.166114 Content Loss: 19.502331
#
# run [37750]:
# Style Loss : 1.166074 Content Loss: 19.502302
#
# run [37800]:
# Style Loss : 1.166036 Content Loss: 19.502287
#
# run [37850]:
# Style Loss : 1.165997 Content Loss: 19.502272
#
# run [37900]:
# Style Loss : 1.165942 Content Loss: 19.502270
#
# run [37950]:
# Style Loss : 1.165872 Content Loss: 19.502277
#
# run [38000]:
# Style Loss : 1.165804 Content Loss: 19.502295
#
# run [38050]:
# Style Loss : 1.165775 Content Loss: 19.502270
#
# run [38100]:
# Style Loss : 1.165762 Content Loss: 19.502224
#
# run [38150]:
# Style Loss : 1.165745 Content Loss: 19.502180
#
# run [38200]:
# Style Loss : 1.165746 Content Loss: 19.502121
#
# run [38250]:
# Style Loss : 1.165773 Content Loss: 19.502043
#
# run [38300]:
# Style Loss : 1.165799 Content Loss: 19.501972
#
# run [38350]:
# Style Loss : 1.165828 Content Loss: 19.501904
#
# run [38400]:
# Style Loss : 1.165849 Content Loss: 19.501837
#
# run [38450]:
# Style Loss : 1.165849 Content Loss: 19.501797
#
# run [38500]:
# Style Loss : 1.165820 Content Loss: 19.501781
#
# run [38550]:
# Style Loss : 1.165782 Content Loss: 19.501780
#
# run [38600]:
# Style Loss : 1.165750 Content Loss: 19.501768
#
# run [38650]:
# Style Loss : 1.165664 Content Loss: 19.501806
#
# run [38700]:
# Style Loss : 1.165558 Content Loss: 19.501856
#
# run [38750]:
# Style Loss : 1.165487 Content Loss: 19.501877
#
# run [38800]:
# Style Loss : 1.165428 Content Loss: 19.501884
#
# run [38850]:
# Style Loss : 1.165334 Content Loss: 19.501915
#
# run [38900]:
# Style Loss : 1.165294 Content Loss: 19.501904
#
# run [38950]:
# Style Loss : 1.165265 Content Loss: 19.501879
#
# run [39000]:
# Style Loss : 1.165252 Content Loss: 19.501831
#
# run [39050]:
# Style Loss : 1.165274 Content Loss: 19.501757
#
# run [39100]:
# Style Loss : 1.165297 Content Loss: 19.501673
#
# run [39150]:
# Style Loss : 1.165330 Content Loss: 19.501579
#
# run [39200]:
# Style Loss : 1.165372 Content Loss: 19.501474
#
# run [39250]:
# Style Loss : 1.165369 Content Loss: 19.501413
#
# run [39300]:
# Style Loss : 1.165361 Content Loss: 19.501354
#
# run [39350]:
# Style Loss : 1.165320 Content Loss: 19.501322
#
# run [39400]:
# Style Loss : 1.165255 Content Loss: 19.501318
#
# run [39450]:
# Style Loss : 1.165198 Content Loss: 19.501318
#
# run [39500]:
# Style Loss : 1.165121 Content Loss: 19.501337
#
# run [39550]:
# Style Loss : 1.165055 Content Loss: 19.501352
#
# run [39600]:
# Style Loss : 1.164957 Content Loss: 19.501400
#
# run [39650]:
# Style Loss : 1.164855 Content Loss: 19.501444
#
# run [39700]:
# Style Loss : 1.164788 Content Loss: 19.501450
#
# run [39750]:
# Style Loss : 1.164729 Content Loss: 19.501453
#
# run [39800]:
# Style Loss : 1.164701 Content Loss: 19.501434
#
# run [39850]:
# Style Loss : 1.164670 Content Loss: 19.501411
#
# run [39900]:
# Style Loss : 1.164584 Content Loss: 19.501442
#
# run [39950]:
# Style Loss : 1.164480 Content Loss: 19.501480
#
# run [40000]:
# Style Loss : 1.164378 Content Loss: 19.501522
#
# run [40050]:
# Style Loss : 1.164298 Content Loss: 19.501543
#
# run [40100]:
# Style Loss : 1.164200 Content Loss: 19.501587
#
# run [40150]:
# Style Loss : 1.164116 Content Loss: 19.501619
#
# run [40200]:
# Style Loss : 1.164024 Content Loss: 19.501652
#
# run [40250]:
# Style Loss : 1.163956 Content Loss: 19.501669
#
# run [40300]:
# Style Loss : 1.163921 Content Loss: 19.501652
#
# run [40350]:
# Style Loss : 1.163889 Content Loss: 19.501631
#
# run [40400]:
# Style Loss : 1.163875 Content Loss: 19.501593
#
# run [40450]:
# Style Loss : 1.163859 Content Loss: 19.501556
#
# run [40500]:
# Style Loss : 1.163839 Content Loss: 19.501528
#
# run [40550]:
# Style Loss : 1.163811 Content Loss: 19.501507
#
# run [40600]:
# Style Loss : 1.163777 Content Loss: 19.501488
#
# run [40650]:
# Style Loss : 1.163748 Content Loss: 19.501455
#
# run [40700]:
# Style Loss : 1.163718 Content Loss: 19.501434
#
# run [40750]:
# Style Loss : 1.163673 Content Loss: 19.501417
#
# run [40800]:
# Style Loss : 1.163648 Content Loss: 19.501385
#
# run [40850]:
# Style Loss : 1.163625 Content Loss: 19.501350
#
# run [40900]:
# Style Loss : 1.163615 Content Loss: 19.501305
#
# run [40950]:
# Style Loss : 1.163605 Content Loss: 19.501263
#
# run [41000]:
# Style Loss : 1.163584 Content Loss: 19.501234
#
# run [41050]:
# Style Loss : 1.163560 Content Loss: 19.501219
#
# run [41100]:
# Style Loss : 1.163551 Content Loss: 19.501190
#
# run [41150]:
# Style Loss : 1.163539 Content Loss: 19.501162
#
# run [41200]:
# Style Loss : 1.163516 Content Loss: 19.501137
#
# run [41250]:
# Style Loss : 1.163447 Content Loss: 19.501150
#
# run [41300]:
# Style Loss : 1.163357 Content Loss: 19.501186
#
# run [41350]:
# Style Loss : 1.163259 Content Loss: 19.501230
#
# run [41400]:
# Style Loss : 1.163174 Content Loss: 19.501263
#
# run [41450]:
# Style Loss : 1.163118 Content Loss: 19.501261
#
# run [41500]:
# Style Loss : 1.163080 Content Loss: 19.501251
#
# run [41550]:
# Style Loss : 1.163072 Content Loss: 19.501215
#
# run [41600]:
# Style Loss : 1.163066 Content Loss: 19.501177
#
# run [41650]:
# Style Loss : 1.163079 Content Loss: 19.501110
#
# run [41700]:
# Style Loss : 1.163109 Content Loss: 19.501030
#
# run [41750]:
# Style Loss : 1.163112 Content Loss: 19.500975
#
# run [41800]:
# Style Loss : 1.163106 Content Loss: 19.500935
#
# run [41850]:
# Style Loss : 1.163107 Content Loss: 19.500883
#
# run [41900]:
# Style Loss : 1.163094 Content Loss: 19.500853
#
# run [41950]:
# Style Loss : 1.163087 Content Loss: 19.500813
#
# run [42000]:
# Style Loss : 1.163041 Content Loss: 19.500793
#
# run [42050]:
# Style Loss : 1.162979 Content Loss: 19.500799
#
# run [42100]:
# Style Loss : 1.162944 Content Loss: 19.500780
#
# run [42150]:
# Style Loss : 1.162891 Content Loss: 19.500763
#
# run [42200]:
# Style Loss : 1.162836 Content Loss: 19.500746
#
# run [42250]:
# Style Loss : 1.162741 Content Loss: 19.500769
#
# run [42300]:
# Style Loss : 1.162637 Content Loss: 19.500788
#
# run [42350]:
# Style Loss : 1.162565 Content Loss: 19.500782
#
# run [42400]:
# Style Loss : 1.162557 Content Loss: 19.500719
#
# run [42450]:
# Style Loss : 1.162574 Content Loss: 19.500631
#
# run [42500]:
# Style Loss : 1.162634 Content Loss: 19.500502
#
# run [42550]:
# Style Loss : 1.162679 Content Loss: 19.500378
#
# run [42600]:
# Style Loss : 1.162698 Content Loss: 19.500286
#
# run [42650]:
# Style Loss : 1.162687 Content Loss: 19.500221
#
# run [42700]:
# Style Loss : 1.162668 Content Loss: 19.500168
#
# run [42750]:
# Style Loss : 1.162655 Content Loss: 19.500113
#
# run [42800]:
# Style Loss : 1.162652 Content Loss: 19.500046
#
# run [42850]:
# Style Loss : 1.162626 Content Loss: 19.499994
#
# run [42900]:
# Style Loss : 1.162551 Content Loss: 19.499992
#
# run [42950]:
# Style Loss : 1.162518 Content Loss: 19.499962
#
# run [43000]:
# Style Loss : 1.162524 Content Loss: 19.499889
#
# run [43050]:
# Style Loss : 1.162490 Content Loss: 19.499849
#
# run [43100]:
# Style Loss : 1.162395 Content Loss: 19.499876
#
# run [43150]:
# Style Loss : 1.162309 Content Loss: 19.499884
#
# run [43200]:
# Style Loss : 1.162197 Content Loss: 19.499924
#
# run [43250]:
# Style Loss : 1.162177 Content Loss: 19.499880
#
# run [43300]:
# Style Loss : 1.162132 Content Loss: 19.499853
#
# run [43350]:
# Style Loss : 1.162097 Content Loss: 19.499821
#
# run [43400]:
# Style Loss : 1.162040 Content Loss: 19.499815
#
# run [43450]:
# Style Loss : 1.162011 Content Loss: 19.499786
#
# run [43500]:
# Style Loss : 1.162002 Content Loss: 19.499746
#
# run [43550]:
# Style Loss : 1.162000 Content Loss: 19.499701
#
# run [43600]:
# Style Loss : 1.161989 Content Loss: 19.499664
#
# run [43650]:
# Style Loss : 1.161967 Content Loss: 19.499640
#
# run [43700]:
# Style Loss : 1.161940 Content Loss: 19.499622
#
# run [43750]:
# Style Loss : 1.161903 Content Loss: 19.499619
#
# run [43800]:
# Style Loss : 1.161874 Content Loss: 19.499609
#
# run [43850]:
# Style Loss : 1.161834 Content Loss: 19.499613
#
# run [43900]:
# Style Loss : 1.161796 Content Loss: 19.499615
#
# run [43950]:
# Style Loss : 1.161773 Content Loss: 19.499605
#
# run [44000]:
# Style Loss : 1.161748 Content Loss: 19.499594
#
# run [44050]:
# Style Loss : 1.161711 Content Loss: 19.499590
#
# run [44100]:
# Style Loss : 1.161686 Content Loss: 19.499577
#
# run [44150]:
# Style Loss : 1.161663 Content Loss: 19.499565
#
# run [44200]:
# Style Loss : 1.161620 Content Loss: 19.499571
#
# run [44250]:
# Style Loss : 1.161566 Content Loss: 19.499586
#
# run [44300]:
# Style Loss : 1.161505 Content Loss: 19.499613
#
# run [44350]:
# Style Loss : 1.161439 Content Loss: 19.499643
#
# run [44400]:
# Style Loss : 1.161387 Content Loss: 19.499662
#
# run [44450]:
# Style Loss : 1.161355 Content Loss: 19.499664
#
# run [44500]:
# Style Loss : 1.161324 Content Loss: 19.499664
#
# run [44550]:
# Style Loss : 1.161258 Content Loss: 19.499699
#
# run [44600]:
# Style Loss : 1.161198 Content Loss: 19.499731
#
# run [44650]:
# Style Loss : 1.161137 Content Loss: 19.499760
#
# run [44700]:
# Style Loss : 1.161088 Content Loss: 19.499777
#
# run [44750]:
# Style Loss : 1.161035 Content Loss: 19.499804
#
# run [44800]:
# Style Loss : 1.160983 Content Loss: 19.499826
#
# run [44850]:
# Style Loss : 1.160942 Content Loss: 19.499838
#
# run [44900]:
# Style Loss : 1.160890 Content Loss: 19.499857
#
# run [44950]:
# Style Loss : 1.160858 Content Loss: 19.499859
#
# run [45000]:
# Style Loss : 1.160832 Content Loss: 19.499855
#
# run [45050]:
# Style Loss : 1.160797 Content Loss: 19.499861
#
# run [45100]:
# Style Loss : 1.160752 Content Loss: 19.499872
#
# run [45150]:
# Style Loss : 1.160712 Content Loss: 19.499886
#
# run [45200]:
# Style Loss : 1.160676 Content Loss: 19.499895
#
# run [45250]:
# Style Loss : 1.160624 Content Loss: 19.499916
#
# run [45300]:
# Style Loss : 1.160588 Content Loss: 19.499922
#
# run [45350]:
# Style Loss : 1.160575 Content Loss: 19.499907
#
# run [45400]:
# Style Loss : 1.160570 Content Loss: 19.499884
#
# run [45450]:
# Style Loss : 1.160568 Content Loss: 19.499855
#
# run [45500]:
# Style Loss : 1.160577 Content Loss: 19.499809
#
# run [45550]:
# Style Loss : 1.160574 Content Loss: 19.499781
#
# run [45600]:
# Style Loss : 1.160569 Content Loss: 19.499750
#
# run [45650]:
# Style Loss : 1.160560 Content Loss: 19.499722
#
# run [45700]:
# Style Loss : 1.160537 Content Loss: 19.499712
#
# run [45750]:
# Style Loss : 1.160523 Content Loss: 19.499693
#
# run [45800]:
# Style Loss : 1.160511 Content Loss: 19.499672
#
# run [45850]:
# Style Loss : 1.160510 Content Loss: 19.499638
#
# run [45900]:
# Style Loss : 1.160514 Content Loss: 19.499603
#
# run [45950]:
# Style Loss : 1.160524 Content Loss: 19.499561
#
# run [46000]:
# Style Loss : 1.160517 Content Loss: 19.499540
#
# run [46050]:
# Style Loss : 1.160515 Content Loss: 19.499517
#
# run [46100]:
# Style Loss : 1.160517 Content Loss: 19.499487
#
# run [46150]:
# Style Loss : 1.160518 Content Loss: 19.499462
#
# run [46200]:
# Style Loss : 1.160520 Content Loss: 19.499432
#
# run [46250]:
# Style Loss : 1.160528 Content Loss: 19.499392
#
# run [46300]:
# Style Loss : 1.160524 Content Loss: 19.499369
#
# run [46350]:
# Style Loss : 1.160518 Content Loss: 19.499344
#
# run [46400]:
# Style Loss : 1.160513 Content Loss: 19.499325
#
# run [46450]:
# Style Loss : 1.160524 Content Loss: 19.499285
#
# run [46500]:
# Style Loss : 1.160526 Content Loss: 19.499254
#
# run [46550]:
# Style Loss : 1.160545 Content Loss: 19.499207
#
# run [46600]:
# Style Loss : 1.160560 Content Loss: 19.499159
#
# run [46650]:
# Style Loss : 1.160579 Content Loss: 19.499107
#
# run [46700]:
# Style Loss : 1.160604 Content Loss: 19.499046
#
# run [46750]:
# Style Loss : 1.160621 Content Loss: 19.498997
#
# run [46800]:
# Style Loss : 1.160623 Content Loss: 19.498964
#
# run [46850]:
# Style Loss : 1.160615 Content Loss: 19.498941
#
# run [46900]:
# Style Loss : 1.160595 Content Loss: 19.498930
#
# run [46950]:
# Style Loss : 1.160579 Content Loss: 19.498922
#
# run [47000]:
# Style Loss : 1.160572 Content Loss: 19.498903
#
# run [47050]:
# Style Loss : 1.160566 Content Loss: 19.498886
#
# run [47100]:
# Style Loss : 1.160557 Content Loss: 19.498869
#
# run [47150]:
# Style Loss : 1.160566 Content Loss: 19.498831
#
# run [47200]:
# Style Loss : 1.160591 Content Loss: 19.498774
#
# run [47250]:
# Style Loss : 1.160619 Content Loss: 19.498713
#
# run [47300]:
# Style Loss : 1.160668 Content Loss: 19.498627
#
# run [47350]:
# Style Loss : 1.160696 Content Loss: 19.498568
#
# run [47400]:
# Style Loss : 1.160757 Content Loss: 19.498472
#
# run [47450]:
# Style Loss : 1.160822 Content Loss: 19.498367
#
# run [47500]:
# Style Loss : 1.160860 Content Loss: 19.498299
#
# run [47550]:
# Style Loss : 1.160871 Content Loss: 19.498255
#
# run [47600]:
# Style Loss : 1.160890 Content Loss: 19.498203
#
# run [47650]:
# Style Loss : 1.160908 Content Loss: 19.498150
#
# run [47700]:
# Style Loss : 1.160954 Content Loss: 19.498062
#
# run [47750]:
# Style Loss : 1.160961 Content Loss: 19.498016
#
# run [47800]:
# Style Loss : 1.160940 Content Loss: 19.497990
#
# run [47850]:
# Style Loss : 1.160927 Content Loss: 19.497963
#
# run [47900]:
# Style Loss : 1.160899 Content Loss: 19.497948
#
# run [47950]:
# Style Loss : 1.160869 Content Loss: 19.497940
#
# run [48000]:
# Style Loss : 1.160825 Content Loss: 19.497944
#
# run [48050]:
# Style Loss : 1.160750 Content Loss: 19.497963
#
# run [48100]:
# Style Loss : 1.160671 Content Loss: 19.497997
#
# run [48150]:
# Style Loss : 1.160593 Content Loss: 19.498024
#
# run [48200]:
# Style Loss : 1.160532 Content Loss: 19.498039
#
# run [48250]:
# Style Loss : 1.160469 Content Loss: 19.498062
#
# run [48300]:
# Style Loss : 1.160424 Content Loss: 19.498068
#
# run [48350]:
# Style Loss : 1.160352 Content Loss: 19.498102
#
# run [48400]:
# Style Loss : 1.160301 Content Loss: 19.498117
#
# run [48450]:
# Style Loss : 1.160249 Content Loss: 19.498137
#
# run [48500]:
# Style Loss : 1.160220 Content Loss: 19.498138
#
# run [48550]:
# Style Loss : 1.160189 Content Loss: 19.498137
#
# run [48600]:
# Style Loss : 1.160167 Content Loss: 19.498135
#
# run [48650]:
# Style Loss : 1.160134 Content Loss: 19.498137
#
# run [48700]:
# Style Loss : 1.160085 Content Loss: 19.498159
#
# run [48750]:
# Style Loss : 1.160056 Content Loss: 19.498161
#
# run [48800]:
# Style Loss : 1.160028 Content Loss: 19.498165
#
# run [48850]:
# Style Loss : 1.159992 Content Loss: 19.498178
#
# run [48900]:
# Style Loss : 1.159963 Content Loss: 19.498184
#
# run [48950]:
# Style Loss : 1.159923 Content Loss: 19.498196
#
# run [49000]:
# Style Loss : 1.159900 Content Loss: 19.498192
#
# run [49050]:
# Style Loss : 1.159886 Content Loss: 19.498180
#
# run [49100]:
# Style Loss : 1.159868 Content Loss: 19.498169
#
# run [49150]:
# Style Loss : 1.159844 Content Loss: 19.498169
#
# run [49200]:
# Style Loss : 1.159814 Content Loss: 19.498169
#
# run [49250]:
# Style Loss : 1.159788 Content Loss: 19.498171
#
# run [49300]:
# Style Loss : 1.159759 Content Loss: 19.498171
#
# run [49350]:
# Style Loss : 1.159740 Content Loss: 19.498159
#
# run [49400]:
# Style Loss : 1.159740 Content Loss: 19.498131
#
# run [49450]:
# Style Loss : 1.159730 Content Loss: 19.498117
#
# run [49500]:
# Style Loss : 1.159711 Content Loss: 19.498112
#
# run [49550]:
# Style Loss : 1.159678 Content Loss: 19.498121
#
# run [49600]:
# Style Loss : 1.159649 Content Loss: 19.498123
#
# run [49650]:
# Style Loss : 1.159632 Content Loss: 19.498112
#
# run [49700]:
# Style Loss : 1.159629 Content Loss: 19.498085
#
# run [49750]:
# Style Loss : 1.159639 Content Loss: 19.498047
#
# run [49800]:
# Style Loss : 1.159635 Content Loss: 19.498018
#
# run [49850]:
# Style Loss : 1.159639 Content Loss: 19.497984
#
# run [49900]:
# Style Loss : 1.159648 Content Loss: 19.497942
#
# run [49950]:
# Style Loss : 1.159652 Content Loss: 19.497911
#
# run [50000]:
# Style Loss : 1.159664 Content Loss: 19.497871
